# %%
from tensorflow.keras.models import load_model
from tensorflow.python.keras.activations import softmax
from custom import cat_acc, cce, plate_acc, top_3_k
from keras.utils.vis_utils import plot_model
import pydot
import graphviz

# %%
custom_objects = {
        'cce': cce,
        'cat_acc': cat_acc,
        'plate_acc': plate_acc,
        'top_3_k': top_3_k,
        'softmax': softmax
    }

# %%
model = load_model('m1_93_vpa_2.0M-i2.h5', custom_objects=custom_objects)
model.summary()
# Out:
# Model: "functional_31"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_16 (InputLayer)           [(None, 70, 140, 1)] 0
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 70, 140, 64)  576         input_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 70, 140, 64)  256         conv2d_141[0][0]
# __________________________________________________________________________________________________
# activation_246 (Activation)     (None, 70, 140, 64)  0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# ...

# %%
plot_model(model, to_file='model1_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
# !python detect_video.py --weights ./checkpoints/custom-416 --size 416 --model yolov4 --video ./data/video/raizen.mp4 --output ./detections/results.avi --plate
# Out:
# License Plate #: EQT998_
# Confidence: [0.11717397 0.38960925 0.8193729  0.73548496 0.21994889 0.6227635
#  0.81720346]
# FPS: 0.68
# License Plate #: OQT990_
# Confidence: [0.08750484 0.37272894 0.6979426  0.72254914 0.24965031 0.27696708
#  0.79396313]
# FPS: 1.03
# License Plate #: EQT990_
# Confidence: [0.11910209 0.50168234 0.7415653  0.77638704 0.16066593 0.21583116
#  0.7843864 ]
# FPS: 1.08
# License Plate #: EOT990_
# Confidence: [0.12921306 0.13022248 0.742622   0.76688206 0.26704392 0.42218268
#  0.8290072 ]
# FPS: 1.06
# License Plate #: EAT900_
# Confidence: [0.14494506 0.32435092 0.7086055  0.6019462  0.27485427 0.32031927
#  0.7916567 ]
# FPS: 1.15
# License Plate #: EQT900_
# Confidence: [0.20351979 0.10816047 0.64317507 0.7172912  0.28105482 0.27815154
#  0.7992158 ]
# FPS: 1.14
# License Plate #: EOT900_
# Confidence: [0.11955465 0.19694448 0.74666035 0.6921528  0.20740834 0.32435346
#  0.8011277 ]
# FPS: 1.17
# License Plate #: EOT980_
# ...

# %%
# !python detect.py --weights ./checkpoints/custom-416 --size 416 --model yolov4 --images ./data/images/patente1.jpg --crop --info --plate
# Out:
# License Plate #: ONS387_
# Confidence: [0.7429366  0.7985276  0.6533118  0.78111243 0.8702679  0.8537062
#  0.8130593 ]
# Object found: license_plate, Confidence: 0.78, BBox Coords (xmin, ymin, xmax, ymax): 328.0, 548.0, 382.0, 572.0
# License Plate #: AB574EO
# Confidence: [0.7898957  0.5299936  0.5356286  0.38447312 0.31302595 0.70787746
#  0.24870625]
# Object found: license_plate, Confidence: 0.75, BBox Coords (xmin, ymin, xmax, ymax): 1003.0, 404.0, 1054.0, 426.0

# %%
# !python train.py --epochs 100 --lr 0.001 --batch-size 32 --height 70 --width 140 --graficos --cut-out --val-annotations "./train_val_set/valid_anotaciones.txt"
# Out:
# Epoch 1/10
#
# ...
# 3/3 [==============================] - 4s 1s/step - loss: 28.6448 - cat_acc: 0.0293 - plate_acc: 0.0000e+00 - top_3_k: 0.0938 - val_loss: 27.5252 - val_cat_acc: 0.0536 - val_plate_acc: 0.0000e+00 - val_top_3_k: 0.1339
# Epoch 2/10
#
# ...
# 3/3 [==============================] - 4s 1s/step - loss: 27.1759 - cat_acc: 0.0704 - plate_acc: 0.0000e+00 - top_3_k: 0.1548 - val_loss: 26.2708 - val_cat_acc: 0.0446 - val_plate_acc: 0.0000e+00 - val_top_3_k: 0.2455
# Epoch 3/10
#
# ...
# 3/3 [==============================] - 6s 2s/step - loss: 25.8126 - cat_acc: 0.1086 - plate_acc: 0.0000e+00 - top_3_k: 0.2470 - val_loss: 24.9975 - val_cat_acc: 0.0625 - val_plate_acc: 0.0000e+00 - val_top_3_k: 0.2455
# Epoch 4/10
#
# ...
# 3/3 [==============================] - 6s 2s/step - loss: 24.4094 - cat_acc: 0.1161 - plate_acc: 0.0000e+00 - top_3_k: 0.2396 - val_loss: 23.7644 - val_cat_acc: 0.0580 - val_plate_acc: 0.0000e+00 - val_top_3_k: 0.2321
# Epoch 5/10
#
# ...
